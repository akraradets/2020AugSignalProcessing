# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
pi = np.pi

from scipy import signal
import scipy.integrate as integrate

# %%
def f(t):
  return t**2

# %%
# t = 0.01:14
t = np.linspace(0.01,14,)
# 2 * pi * f
f = 0.1
# y = signal.square(t * pi / 5)
y = signal.square(t * 2 * pi * f)
plt.plot(t,y)

# %%
result = integrate.quad(f, 0, 1)
result[0]
# Out:
# 0.33333333333333337

# %%
# # T = 1/f
# a0 = integrate.quad(funcAn,0,T)[0] / T
# a0
# b0 = integrate.quad(funcBn,0,T)[0] *2  / T
# b0
t = np.arange(0,15,0.01)
signal = np.zeros(len(t))
for i in range(1,500,2):
    # print(i)
    coff = (4/(pi*i))
    v = coff * np.sin(i * pi / 5 * t)
    signal = signal + v
    # sum = sum + (4/(pi*i))
# print(sum,b0)

plt.plot(t,signal)

# %%
f = 0.1
w0 = 2 * pi * f
t = np.arange(0,15,0.01)

def Vn(n):
    return signal.square(w0 * n * t)

def funcA0(n):
    s1 = Vn(n) 
    return s1

def funcAn(n):
    # n * w0 * t
    s1 = Vn(n)
    s2 = np.cos(n * w0 * t)
    return s1 * s2

def funcBn(n):
    s1 = Vn(n)
    s2 = np.sin(n * w0 * t)
    return s1 * s2

plt.plot(Vn(1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-b913aee407d3> in <module>
#      21     return s1 * s2
#      22
# ---> 23 plt.plot(Vn(1))
#
# <ipython-input-80-b913aee407d3> in Vn(n)
#       4
#       5 def Vn(n):
# ----> 6     return signal.square(w0 * n * t)
#       7
#       8 def funcA0(n):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'square'

# %% [markdown]
# 1. Implement Fourier Series (Sinusoial form) as a function
#
# 2. Generate 3 functions using symbolic constant
# - square wave
# - sawtooth
# - your choice
#
# 3. show the output in N = 10,50,100
